# %% [markdown]
# # MODULO 1: PROYECTO DE EVALUACIÓN

# %% [markdown]
# # 1. Estructura
# - Tres estructuras iniciales con las que trabajaremos a lo largo de la evaluación:

# %%
#1º ESTRUCTURA: se trata de un inventario (de una lista de diccionarios), no obstante, comenzaremos con una lista vacía.
inventario = [] 
type(inventario)
# Out:
# list

# %%
#2 ESTRUCTURA: creación de un diccionario para llevar un registro de los clientes de la tienda. 
clientes ={
    'Ana García': {'email': 'ana.garcia@email.com', 'compras': []},
    'Luis Fernández': {'email': 'luis.fernandez@email.com', 'compras': []},
    'María López': {'email': 'maria.lopez@email.com', 'compras': []},
    'Carlos Ruiz': {'email': 'carlos.ruiz@email.com', 'compras': []},
    'Elena Martín': {'email': 'elena.martin@email.com', 'compras': []},
    'Javier Torres': {'email': 'javier.torres@email.com', 'compras': []},
    'Lucía Sánchez': {'email': 'lucia.sanchez@email.com', 'compras': []},
    'Sergio Díaz': {'email': 'sergio.diaz@email.com', 'compras': []},
    'Patricia Ramos': {'email': 'patricia.ramos@email.com', 'compras': []},
    'Diego Navarro': {'email': 'diego.navarro@email.com', 'compras': []}
}
type(clientes)
# Out:
# dict

# %%
#3 ESTRUCTURA: creación de una variable para llevar un registro de las ventas totales de la tienda. 
ventas_totales = 0.00
type(ventas_totales)
# Out:
# float

# %% [markdown]
# # 2. Funciones

# %% [markdown]
# #
# 1. agregar_producto(nombre, precio, cantidad): Agrega un producto al inventario o actualiza su cantidad si ya existe. Debe recibir el nombre, precio y cantidad del producto como parámetros.
#     - Itera a través del inventario y compara los nombres de los productos con el nombre proporcionado.
#     - Si el producto ya existe, actualiza la cantidad.
#     - Si no existe, agrega un nuevo producto al inventario.

# %%
inventario = []

# %%
def agregar_producto(nombre, precio, cantidad):
    for producto in inventario:
        if producto["nombre"] == nombre:
            producto["cantidad"] += cantidad
            return
    else:
        inventario.append({"nombre": nombre, "precio": precio, "cantidad": cantidad})

# %%
agregar_producto("Camisa", 20, 40)
agregar_producto("Pantalón", 30, 30)
agregar_producto("Zapatos", 50, 25)

# %%
agregar_producto("Camisa", 20, 10)

# %%
inventario
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 50},
#  {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
#  {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}]

# %% [markdown]
# #
# 2. ver_inventario(): Muestra el inventario de productos con sus detalles.
#     - Utiliza un bucle for para recorrer el inventario.
#     - Imprime los detalles (nombre, precio, cantidad) de cada producto.

# %%
def ver_inventario():
    for producto in inventario:
        print("Nombre:", producto["nombre"], "Precio:", producto["precio"], "Cantidad:", producto["cantidad"])

# %%
ver_inventario()
# Out:
# Nombre: Camisa Precio: 20 Cantidad: 50
# Nombre: Pantalón Precio: 30 Cantidad: 30
# Nombre: Zapatos Precio: 50 Cantidad: 25

# %%
#Aunque sea correcto, no me devuelve las comas como en el ejemplo (ni el $), para ello utilizar f-string:
def ver_inventario():
    for producto in inventario:
        print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")

# %%
ver_inventario()
# Out:
# Nombre: Camisa, Precio: $20, Cantidad: 50
# Nombre: Pantalón, Precio: $30, Cantidad: 30
# Nombre: Zapatos, Precio: $50, Cantidad: 25

# %% [markdown]
# #
# 3. buscar_producto(nombre): Busca un producto en el inventario por nombre y muestra sus detalles si se encuentra. Debe recibir el nombre del producto como parámetro.

# %%
def buscar_producto(nombre):
    for producto in inventario:
        if producto["nombre"] == nombre:
            print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")
            return
    else:
        print("Producto no encontrado")

# %%
#me va a devolver que la cantidad de camisas son 50 porque antes he añadido 10 más como prueba
buscar_producto("Camisa")
# Out:
# Nombre: Camisa, Precio: $20, Cantidad: 50

# %%
buscar_producto("Vestido")
# Out:
# Producto no encontrado

# %% [markdown]
# #
# 4. actualizar_stock(nombre, cantidad): Actualiza el stock de un producto en el inventario. Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.
#     - Utiliza un bucle for para recorrer el inventario.
#     - Busca el producto por nombre.
#     - Actualiza la cantidad según la entrada del usuario.
#     - Si el producto no esta en el inventario muestra un mensaje indicándolo.

# %%
def actualizar_stock(nombre, cantidad):
    for producto in inventario:
        if producto["nombre"] == nombre:
            producto["cantidad"] += cantidad
            print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']}, Cantidad: {producto['cantidad']}")
            return
    else: 
        print("No existe este producto en el inventario")

# %%
actualizar_stock("Zapatos", 25)
# Out:
# Nombre: Zapatos, Precio: $50, Cantidad: 50

# %%
actualizar_stock("Vestido", 10)
# Out:
# No existe este producto en el inventario

# %% [markdown]
# #
# 5. eliminar_producto(nombre): Elimina un producto del inventario por nombre. Debe recibir el nombre del producto como parámetro.
#     - Utiliza un bucle for para recorrer el inventario.
#     - Busca el producto por nombre.
#     - Elimina el producto del inventario si existe.
#     - Si el producto no esta en el inventario muestra un mensaje indicándolo.

# %%
inventario = [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 50},
 {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
 {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}]

# %%
def eliminar_producto(nombre):
    for producto in inventario:
        if producto["nombre"] == nombre:
            inventario.remove(producto)
            print("El producto ha sido eliminado")
            return
    else: 
        print("El producto no está en el inventario")

# %%
eliminar_producto("Zapatos")
# Out:
# El producto ha sido eliminado

# %%
eliminar_producto("Vestidos")
# Out:
# El producto no está en el inventario

# %% [markdown]
# #
# 6. calcular_valor_inventario(): Calcula y muestra el valor total del inventario.
#     - Utiliza un bucle for para calcular el valor total del inventario.
#     - Itera a través del inventario y suma el valor de cada producto (precio x cantidad).

# %%
inventario = [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},
  {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
  {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25},
  {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15},
  {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]

# %%
def calcular_valor_inventario():
    total = 0 
    for producto in inventario:
        total += producto["precio"] * producto["cantidad"]
    print(f"El valor total del inventario es de {total}€")

# %%
calcular_valor_inventario()
# Out:
# El valor total del inventario es de 4500€

# %% [markdown]
# #
# 7. realizar_compra(): Permite a un cliente realizar una compra seleccionando productos del inventario. Debe interactuar con el cliente para seleccionar productos y calcular el costo total de la compra.
#     - Utiliza un bucle while para permitir al cliente realizar múltiples compras.
#     - Muestra el inventario y solicita al cliente ingresar el nombre del producto que desea comprar.
#     - Registra los productos seleccionados en un carrito y actualiza el inventario.
#     - Calcula el costo total de la compra.

# %%
def realizar_compra():
    carrito = []
    total2 = 0
    
    while True:
        compra = input("¿Qué producto quieres comprar? Cuando acabes dime STOP para dejar de añadir productos a la cesta")
        if compra == "STOP":
            break 

        for producto in inventario:
            if producto["nombre"].lower() == compra.lower(): #si dentro de compra está el producto de nuestro inventario...
                carrito.append(producto["nombre"]) #añade al carrito ese mismo producto ya que lo tenemos
                producto["cantidad"] -= 1 #actualizo inventario, es decir, me queda 1ud menos de ese producto
                total2 += producto["precio"] #ve sumando los precios de los productos para calcular cuanto ha costado la compra
                print(carrito)
                print(inventario)
                print(total2)
                break
        
        else:
            print("No tenemos el producto dentro de nuestro inventario")

# %%
realizar_compra()
# Out:
# ['Camisa']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 38}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 28}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 20
# ['Camisa', 'Camisa']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 37}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 28}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 40
# ['Camisa', 'Camisa', 'Pantalón']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 37}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 27}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 70
# ['Camisa', 'Camisa', 'Pantalón', 'Zapatos']
# ...

# %%
realizar_compra()
# Out:
# ['Camisa']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 36}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 27}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 24}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 20
# ['Camisa', 'Camisa']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 35}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 27}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 24}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 40
# ['Camisa', 'Camisa', 'Zapatos']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 35}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 27}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 23}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 90
# No tenemos el producto dentro de nuestro inventario

# %%
realizar_compra()
# Out:
# ['Pantalón']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 35}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 26}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 23}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# 30

# %%
realizar_compra()
# Out:
# No tenemos el producto dentro de nuestro inventario

# %%
def realizar_compra():
    carrito = []
    total2 = 0
    
    while True:
        compra = input("¿Qué producto quieres comprar? Cuando acabes dime STOP para dejar de añadir productos a la cesta")
        if compra == "STOP":
            break 

        for producto in inventario:
            if producto["nombre"].lower() == compra.lower(): #si dentro de compra está el producto de nuestro inventario...
                carrito.append(producto["nombre"]) #añade al carrito ese mismo producto ya que lo tenemos
                producto["cantidad"] -= 1 #actualizo inventario, es decir, me queda 1ud menos de ese producto
                total2 += producto["precio"] #ve sumando los precios de los productos para calcular cuanto ha costado la compra
                print(f"Lo que he comprado ha sido: {carrito}")
                print(inventario)
                print(f"El total de lo comprado asciende a {total2}€")
                break
        
        else:
            print("No tenemos el producto dentro de nuestro inventario")

# %%
realizar_compra()
# Out:
# Lo que he comprado ha sido: ['Camisa']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 34}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 26}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 23}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# El total de lo comprado asciende a 20€
# Lo que he comprado ha sido: ['Camisa', 'Pantalón']
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 34}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 25}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 23}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 14}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}]
# El total de lo comprado asciende a 50€
# Lo que he comprado ha sido: ['Camisa', 'Pantalón', 'Zapatos']
# ...

# %%
def realizar_compra():
    carrito = []
    total2 = 0
    
    while True:
        compra = input("¿Qué producto quieres comprar? Cuando acabes dime STOP para dejar de añadir productos a la cesta")
        if compra.lower() == "STOP":
            break 

        for producto in inventario:
            if producto["nombre"].lower() == compra.lower(): #si dentro de compra está el producto de nuestro inventario...
                
                if producto["cantidad"] == 0:
                    print("Ya se nos ha agotado este producto")
                
                elif producto["cantidad"] > 0:
                    carrito.append(producto["nombre"]) #añade al carrito ese mismo producto ya que lo tenemos
                    producto["cantidad"] -= 1 #actualizo inventario, es decir, me queda 1ud menos de ese producto
                    total2 += producto["precio"] #ve sumando los precios de los productos para calcular cuanto ha costado la compra
                    print(f"Lo que he comprado ha sido: {carrito}")
                    print(inventario)
                    print(f"El total de lo comprado asciende a {total2}€")
                
                break
        
        else:
            print("No tenemos el producto dentro de nuestro inventario")

# %% [markdown]
# # NEXT STEPS
# Como futuros pasos a incluir dentro del código que pueden resultar útiles de cara a mejorar los comandos pedidos tenemos:
# 1. **if producto["nombre"] == nombre:** incluir .lower() cuando se trata de comparar el nombre ya almacenado con el nombre que nos ha sido proporcionado para que Python no descarte un caso cuando se introduce el nombre con mayúsculas o minúsculas diferentes. Ya lo he realizado en el ejercicio 7 (línea de código 78) con el producto["nombre"], la compra y el STOP.
#
# 2. **empleo del if/elif para dejar de vender cuando la cantidad es = 0:** en la parte 7, estamos vendiendo por unidades pequeñas, pero si en algún momento nuestro inventario se quedase sin stock de alguno de los productos, sería útil que devolviese un print de "Ya se nos ha agotado este producto", para ello, dentro del propio if, resultaría útil meter un *if producto["cantidad"] == 0:* y un *elif producto["cantidad"] > 0:* antes de seguir con nuestra cadena de comandos (quedaría el código como en la línea 78).
#
# 3. **poner prints específicos para devolver una respuesta coherente:** al igual que en el último caso (línea 75), de forma que no me devuelva solo valores y me devuelva, también, una frase que especifique a qué se refiere dicho valor.
